# %%
import os
os.getcwd()
# Out:
# 'D:\\Data sets'

# %%
os.chdir("D:/Data sets")

# %%
os.getcwd()
# Out:
# 'D:\\Data sets'

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('alcohol2.csv')

# %%
df
# Out:
#     ID  YEAR  COUNTRY  UNEMPLOYEED FEMALE in %  UNEMPLOYED MALE in %  \
# 0    1  2010  Austria                     14.7                  10.3
# 1    2  2010  Estonia                     19.3                   9.4
# 2    3  2010   France                     21.5                   4.6
# 3    4  2010  Ireland                     24.3                  15.3
# 4    5  2010  Germany                     17.8                   7.9
# 5    6  2010    Japan                     14.6                   3.6
# 6    7  2010    Spain                     18.5                   5.6
# 7    8  2010  Finland                     26.1                   8.5
# 8    9  2010   Poland                     29.9                  11.3
# 9   10  2010   Demark                     25.3                  10.4
# 10  11  2010   Canada                     11.9                   3.5
# 11  12  2013  Austria                     14.2                   9.5
# 12  13  2013  Estonia                     18.3                   8.6
# ...

# %%
df.shape
# Out:
# (54, 11)

# %%
del df['ID']

# %%
df.corr()
# Out:
#                                     YEAR  UNEMPLOYEED FEMALE in %  \
# YEAR                            1.000000                -0.347661
# UNEMPLOYEED FEMALE in %        -0.347661                 1.000000
# UNEMPLOYED MALE in %           -0.188034                 0.288620
# AGE 20-30 in l                  0.263148                 0.069354
# AGE30-40 in l                  -0.052752                 0.211030
# TAX ON COUNTRY ALCOHOL in %     0.756905                -0.524385
# TAX ON FOREIGN ALCOHOL          0.680680                -0.260605
# CONSUMPTION OF COUNTRY ALCOHOL  0.468967                -0.090925
# CONSUMPTION OF FOREIGN ALCOHOL  0.274891                 0.139144
#
#                                 UNEMPLOYED MALE in %  AGE 20-30 in l  \
# YEAR                                       -0.188034        0.263148
# UNEMPLOYEED FEMALE in %                     0.288620        0.069354
# UNEMPLOYED MALE in %                        1.000000        0.047068
# ...

# %%
import seaborn as sns
corr = df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)
