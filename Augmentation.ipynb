# %% [markdown]
# <a href="https://colab.research.google.com/github/JyothsnasaiTagirisa/alcohol/blob/master/Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os
import keras
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
image_path='drive/My Drive/Augmentation /cam/'

# %%
os.listdir(image_path)
# Out:
# ['gopif.jpg',
#  'appalanaiduf.jpg',
#  'vijayf.jpg',
#  'suchandarf.jpg',
#  'syamalanaiduf.jpg',
#  'subashf.jpg',
#  'sivaf.jpg',
#  'muniprasadf.jpg',
#  'maniratnaf.jpg',
#  'gprasanthf.jpg',
#  'ayyappaf.jpg',
#  'saikiranf.jpg',
#  'rakeshf.jpg',
#  'nagadathf.jpg',
#  'loknadhvarmaf.jpg',
#  'aprasanthf.jpg',
#  'ajaykumarf.jpg',
#  'saibabaf.jpg',
#  'mohanbalajif.jpg',
#  'praveenf.jpg']

# %%
image_lists = os.listdir(image_path)

# %%
il=[]
for i in image_lists[:]:
  temp_arr=plt.imread(image_path+i)
  il.append(temp_arr)
  #plt.imshow(temp_arr)
  #plt.show()

# %%
gen=ImageDataGenerator(rotation_range=360,width_shift_range=[-200,200],height_shift_range=0.3,shear_range=0.15,zoom_range=[0.5,1.5],brightness_range=(0.1, 0.9),channel_shift_range=150.,horizontal_flip=True,vertical_flip=True)

# %%
single_sample = np.expand_dims(il[20], axis=0)
single_sample.shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-370971dc38eb> in <module>()
# ----> 1 single_sample = np.expand_dims(il[20], axis=0)
#       2 single_sample.shape
#
# IndexError: list index out of range

# %%
itt = gen.flow(single_sample, batch_size=1)

# %%
from tqdm import tnrange, tqdm_notebook

# %%
kali=[]
for i in  tnrange(40):
  gen_array = itt.next()
  kali.append(gen_array)
  gen_image = gen_array[0].astype("uint8")
  #plt.imshow(gen_image)
  #plt.show()
  im=Image.fromarray(gen_image)
  im.save(f"drive/My Drive/Augmentation /dummyt{i}.jpeg")

# %%
im.save?

# %%
from PIL import Image
im=Image.fromarray(gen_image)
im.save("dummy1.jpeg")

# %%
im=Image.fromarray(gen_image)
im.save("dummy1.jpeg")

# %%
kali[0].dtype
# Out:
# dtype('float32')

# %%
for i in kali:
  print (i.dtype)
# Out:
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32

# %%
kali[0].shape
# Out:
# (1, 4608, 3456, 3)

# %%
False in(kali[0]==kali[1])
# Out:
# True

# %%
sameimg=0
for i in range(10):
  for j in range(10):
    if i!=j:
      b=False in(kali[i]==kali[j])
      if b==False:
        sameimg+=1
      #print(f"{i} image and {j} is {b}")

# %%
sameimg
# Out:
# 18

# %%
image=np.expand_dims(temp_arr,axis=0)

# %%
image
# Out:
# array([[[[212, 172, 121],
#          [212, 172, 121],
#          [212, 172, 121],
#          ...,
#          [166, 114,  64],
#          [171, 119,  69],
#          [175, 123,  73]],
#
#         [[213, 173, 122],
#          [213, 173, 122],
#          [212, 172, 121],
#          ...,
#          [170, 118,  68],
#          [173, 121,  71],
#          [170, 118,  68]],
#
#         [[210, 173, 121],
#          [212, 172, 121],
#          [212, 172, 121],
#          ...,
#          [173, 121,  71],
#          [174, 122,  72],
#          [168, 116,  66]],
#
#         ...,
#
#         [[192, 205, 198],
#          [196, 207, 201],
#          [197, 208, 202],
#          ...,
#          [140, 103,  74],
#          [141, 104,  75],
#          [140, 103,  74]],
#
#         [[194, 205, 199],
#          [196, 207, 201],
#          [196, 207, 201],
#          ...,
#          [141, 104,  75],
#          [143, 106,  77],
#          [140, 103,  74]],
#
#         [[198, 209, 201],
# ...

# %%
irr=gen.flow(image)

# %%
image_path
# Out:
# 'drive/My Drive/Augmentation /cam/'

# %%
next(irr[0].astype(np.uint8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-a1b57a432bfa> in <module>()
# ----> 1 next(irr[0].astype(np.uint8))
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/iterator.py in __getitem__(self, idx)
#      63         index_array = self.index_array[self.batch_size * idx:
#      64                                        self.batch_size * (idx + 1)]
# ---> 65         return self._get_batches_of_transformed_samples(index_array)
#      66
#      67     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/numpy_array_iterator.py in _get_batches_of_transformed_samples(self, index_array)
#     149         for i, j in enumerate(index_array):
#     150             x = self.x[j]
# --> 151             params = self.image_data_generator.get_random_transform(x.shape)
# ...
